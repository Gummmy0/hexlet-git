# %% [markdown]
# <a href="https://colab.research.google.com/github/Gummmy0/hexlet-git/blob/main/Copy_of_%D0%9F%D0%BE%D0%B3%D1%80%D1%83%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_DS%2C_%D0%B4%D0%B5%D0%BD%D1%8C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Снимок экрана 2023-09-13 в 18.57.24.png](data:image/png;base64,...)

# %% [markdown]
# # 🔎 Как работать с нотбуком
#
# Мы будем работать с Google Colab - это бесплатная интерактивная облачная среда для работы с кодом от Google (аналог Jupyter Notebook в онлайн версии). Вам не нужно ничего скачивать или устанавливать - просто переходите по ссылке и начнём работу 💥
#
# 1. Чтобы работать с Google Colab, необходимо авторизоваться в своём Google-аккаунте, и затем создать копию у себя на диске - эту опцию можно найти на верхней панели меню в разделе файл (выбираем "создать копию на диске", она сразу же автоматически откроется в новой вкладке - там и нужно работать, теперь это Ваш блокнот, который Вы можете изменять и править).
#  ![03DFD810-627F-4844-B77E-AB91CD97AE2B_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. Ноутбук состоит из ячеек, которые делятся на текстовые и код (примеры ниже в следующей ячейке:)). Ячейки с кодом нужно запускать последовательно - сначала нужно нажать на ячейку, а затем на треугольник запуска слева.
#
# 3. Выполнение одной ячейки может занимать некоторое время, за прогрессом можно следить по вращающемуся кружочку.
#
# 4. По окончании Вы увидите зелёную галочку или красный текст ошибки в случаях успеха или неуспеха соответственно.
#
# 5. Результат выполнения кода ячейки будет отображаться в поле под ней.

# %%
# это ячейка с кодом
# строки с решётками - комментарии, они не распознаютися как код
# а вот следующей строчкой будет идти код печати фразы на экран
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# Это текстовая ячейка, в ней можно красиво форматировать текст при помощи правил MarkDown, можете подробнее почитать про них по ссылке https://paulradzkov.com/2014/markdown_cheatsheet/

# %% [markdown]
# # 🔎 Знакомство с Python

# %% [markdown]
# ### Типы переменных
#
# Главным объектом в Data Science, конечно, являются данные. С точки зрения python все данные "помещаются" в переменные - это некоторое имя, по которому можно обратиться к определённой области памяти в компьютере, где эти данные хранятся. Имя переменной может быть любым, главное, чтобы оно не начиналось с цифры. Также нужно отметить, что в переменные можно положить объекты разных типов (при этом, в отличие от, например, языка С, С++ указывать тип вручную не нужно, он определится автоматически).
#
# Давайте попробуем создать несколько переменных разных типов:

# %%
# создаём переменную-число
number = 5
# переменную-строку
string = 'name'
# переменную-индикатор (булеву)
flag = True
# переменную-массив данных
array = [number, string, flag]
print(array)
# Out:
# [5, 'name', True]

# %% [markdown]
# ### Функции ввода и вывода
#
# Не всегда удобно заполнять значения переменных в коде (например, когда мы хотим получить что-то от пользователя и затем это обработать, вряд ли мы дадим ему доступ к нашему коду:)). Для этого есть возможность ввода данных с клавиатуры прямо во время работы программы.
#
# Есть также и функции вывода (печати) результатов на экран:

# %%
# это функция ввода, она ожидает пока пользователь введёт
# что-нибудь в поле и нажмёт enter
name = input('Введите своё имя: ') # в скобках можно написать подсказку что вводить, но можно и не писать:)
# а это функция вывода
print('Привет,', name)
# Out:
# Введите своё имя: Мария
# Привет, Мария

# %% [markdown]
# ### Арифметические и логические операции
#
# С числами (переменными числовых типов) можно производить обычные математические операции +, -, *, /.
#
# Существуют также логические операции проверки на равенство ==, неравенство != и больше >, меньше <.

# %%
# что-нибудь посчитаем
math_expr = (40 * 10 + 2) / 5
print(math_expr)

# сравним результат
print(math_expr == 50)
print(math_expr != 70)
# Out:
# 80.4
# False
# True

# %% [markdown]
# ### Условные выражения
#
# Удобно составлять условные выражения проверки чего-либо и в случае положительного результата делать какое-нибудь действие. Для этого существуют условные конструкции - давайте посмотрим на пример:

# %%
# сначала пишем if, потом логическое условие, потом с отступом тело условия
# если условие истинно, будет выполняться тело
# если ложно, выполнится то, что находится в ветке else
age = int(input('Введите Ваш возраст: ')) # здесь мы явно привели переменную возраста к числовому типу данных
if age > 12:
    print('Добро пожаловать!')
else:
    print('Вход запрещён:(')

# ветку else, кстати, можно не писать
# тогда в случае неистинности условия просто ничего не выполнится
# Out:
# Введите Ваш возраст: 10

# %%
# условий можно писать несколько
# проверяться они будут последовательно
ans = input('Хотите пирожок? ')
if ans == 'да' or ans == 'Да' or ans == 'ДА':
    print('Держите:)')
    print('ddd')
elif (ans == 'нет'):
    print('Ну ладно до скорого:(')
else:
    print('Я Вас не понял')
# Out:
# Хотите пирожок? Нет
# Я Вас не понял

# %% [markdown]
# Выше, кстати был показан также пример использования конструкции их нескольких условий в if'е, давайте поподробнее:
# - пишем несколько условий, лучше каждое в отдельных скобках
# - между ними можно поставить "и" (and), "или" (or)
# - можете использовать также отрицание условия - для этого используется not
# - PS: скобки можно и не ставить, но тогда нужно учесть, что в этом случае выполнится старндартный приоритет операций: сначала все not, потом and, потом or

# %% [markdown]
# ### Циклы
#
# И последняя новая тема на сегодня - циклы, Это итеративное повторение одного и того же набора действий, пока не выполнится какое-либо условие; посмотрим на синтаксис:

# %%
# сначала пишем ключевое слово while, затем условие, затем тело цикла\
# пока условие истинно, тело цикла будет выполняться
pie_amount = int(input('Введите количество пирожков: '))
while pie_amount < 20:
    print('Это мало, хочу ещё!')
    add = int(input('Введите добавку: '))
    pie_amount = pie_amount + add
print('Спасибо, я наелся:)')
# Out:
# Введите количество пирожков: 10
# Это мало, хочу ещё!
# Введите добавку: 5
# Это мало, хочу ещё!
# Введите добавку: 6
# Спасибо, я наелся:)

# %% [markdown]
# # 🔎 Домашнее задание

# %% [markdown]
# 🌟 Основное преимущество Python в том, что он очень лаконичный и интуитивно понятный:
#  - стоит запомнить ряд правил и конструкций;
#  - также поможет знание английского языка - все ключевые названия имеют в переводе с английского логичное название.
#
# 🌟 При изучении любого языка программирования важно постоянно практиковаться, при самостоятельном использовании в коде изученных методов происходит их автоматическое запоминание.
#
# 🤓 Поэтому в качестве домашнего задания давате попрактикуемся в том, что мы сегодня узнали - Вам предлагается несколько простых заданий на закрепление пройденного материала (некоторые, кстати, взяты из первых недель курса по Data Science). Попробуйте их выполнить:)

# %% [markdown]
# ## ✅ Задание 1
#  Найдите значение выражения $\frac{356\cdot 46}{45 + 976}$ при помощи python

# %%
# ваш код здесь
(356 * 46) / (45 + 976)
# Out:
# 16.039177277179235

# %% [markdown]
# ## ✅ Задание 2
# В компании "Живи и радуйся" можно взять 100 дней отпуска в год. Спросите у работника, сколько дней в году он уже отдохнул и выведите оставшееся количество дней отпуска, доступных ему.

# %%
# ваш код здесь
day_off = int(input('Введите кол-во дней, в которые Вы отдыхали в этой году? '))
print('Вам осталось отдыхать', 100 - day_off, 'дней')
# Out:
# Введите кол-во дней, в которые Вы отдыхали в этой году?10
# Вам осталось отдыхать 90 дней

# %% [markdown]
# ## ✅ Задание 3
# Давайте имитируем авторизацию по логину и паролю на каком-либо сайте. Для этого:
# - попросите сначала пользователя зарегистрироваться - установить логин и пароль (используем input и кладём это в переменные)
# - далее запускаем процесс авторизации: спросим его снова пароль и логин и сравним их с полученными на прошлом шаге эталонами; если они совпадут - сообщите, что авторизация прошла успешно, в противном случае - нет.

# %%
# ваш код здесь
# регистрация
try_login = input('Установите логин ')
try_password = input('Установите пароль ')

# авторизация
login = input('Введите логин ')
password = input('Введите пароль ')

# проверка
if try_login == login and try_password == password:
    print('Авторизация прошла успешно!')
else:
    print('Попробуйте ещё раз')
# Out:
# Установите логин 123
# Установите пароль 123
# Введите логин 123
# Введите пароль 345
# Попробуйте ещё раз

# %% [markdown]
# ## ✅ Задание 4
# Лифт может увезти максимально 800 кг. Создайте программу, которая будет в цикле спрашивать вес каждого входящего, и в случае перевеса сообщит об этом.
#
# Подсказка: создайте переменную-счётчик как в примере с описаниями циклов и обновляйте её значение на каждой итерации.

# %%
# ваш код здесь
weight = int(input('Введите вес первого входящего: '))
while weight <= 800:
    print('Лифт может увезти ещё')
    add = int(input('Введите вес следующего входящего: '))
    weight = weight + add
print('Лифт переполнен')
# Out:
# Введите вес первого входящего: 800
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт переполнен

# %% [markdown]
# ## ✅ Задание 5
# А теперь давайте дополним нашу предыдущую программу: к условию "не более 800 кг" добавьте ещё одно - "не более 8 человек"
#
# Подсказка: вспомните как мы писали несколько уловий в скобках в if - здесь работает аналогичная схема:)

# %%
# ваш код здесь
weight = int(input('Введите вес первого входящего: '))
people_amount = 1
while weight <= 800 and people_amount < 8:
    print('Лифт может увезти ещё')
    add = int(input('Введите вес следующего входящего: '))
    weight = weight + add
    people_amount = people_amount + 1
print('Лифт переполнен')
# Out:
# Введите вес первого входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт может увезти ещё
# Введите вес следующего входящего: 1
# Лифт переполнен

# %% [markdown]
# # 🔎 До встречи завтра!
# В начале проведём разбор решений домашнего задания 🌟
